# %% [markdown]
# ## Test Opencv Read .webm

# %%
import os, sys
sys.path.append('../')
import cv2 as cv
from mylib.utils.imageutils import array_to_img, img_to_array
from mylib.utils.videoutils import load_video
from matplotlib import pyplot as plt
from PIL import Image


FILE_PATH = os.path.dirname(os.path.abspath('__file__'))
VIDEO_PATH = os.path.join(FILE_PATH, '../database/nirvideos/')
VIDEO_URL = os.path.join(VIDEO_PATH, '3_20170324155753.webm')

print VIDEO_URL
# Out:
# /home/jagger/workspace/GlucoseSensor/WebClient/research/../database/nirvideos/3_20170324155753.webm

# %%
video = load_video(VIDEO_URL)

# %%
ret, frame = video.read()
plt.subplot(111)
plt.imshow(frame)
plt.show()

# %%
print isinstance(frame, Image.Image)
# Out:
# True

# %%
print
